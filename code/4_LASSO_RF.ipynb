# %%
# Data Manipulation
import pandas as pd
import numpy as np
import requests
from io import StringIO

# Visualization (Static)
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization (Interactive)
import plotly.express as px

# Machine Learning & Clustering
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeClassifier
# Packages for visualizing the tree
from sklearn.metrics import accuracy_score, f1_score, brier_score_loss
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
# Code for the bootstrap resample
from sklearn.utils import resample
from sklearn.tree import plot_tree

# %% [markdown]
# # Import Data

# %%
 # 1) All variables and countries from the master data
master_data = (pd.read_csv("https://raw.githubusercontent.com/AyaanTigdikar/Capstone/refs/heads/main/MASTER/Master.csv")
               .drop(columns=['Unnamed: 0'], errors='ignore'))


nr = (pd.read_csv("https://raw.githubusercontent.com/AyaanTigdikar/Capstone/refs/heads/main/MASTER/NaturalResource.csv")
               .drop(columns=['Unnamed: 0'], errors='ignore'))


# 2) Clusters list from Leo
clusters_list = pd.read_csv('https://raw.githubusercontent.com/AyaanTigdikar/Capstone/refs/heads/main/workingdata/clusters_list.csv')

# %%
# Suppose your string column is 'Income1995'
# 1. Ensure it’s clean (strip spaces, handle missing values)
master_data['Income1995'] = master_data['Income1995'].astype(str).str.strip()
master_data['Income1995'].replace({'': pd.NA, 'nan': pd.NA}, inplace=True)

# 2. Convert to categorical
master_data['Income1995'] = master_data['Income1995'].astype('category')

# 3. Encode as integer codesx
master_data['Income1995_code'] = master_data['Income1995'].cat.codes

# Define mapping
income_mapping = {
    'Low-income countries': 1,
    'Lower-middle-income countries': 2,
    'Upper-middle-income countries': 3,
    'High-income countries': 4
}

# Apply mapping to create new numeric column
master_data['Income1995_code'] = master_data['Income1995'].map(income_mapping)

master_data = master_data.drop(columns='Income1995')

# %%
# Note: I am replacing the previous master data long with Ayaan's master data
master_data_long = master_data.melt(
    id_vars=['Country Code', 'Country Name', 'Year'],
    var_name= 'Variable',
    value_name='Value'
)

master_data_long
# Out:
#        Country Code Country Name  Year  \
# 0               AGO       Angola  1995
# 1               AGO       Angola  1996
# 2               AGO       Angola  1997
# 3               AGO       Angola  1998
# 4               AGO       Angola  1999
# ...             ...          ...   ...
# 141745          ZWE     Zimbabwe  2015
# 141746          ZWE     Zimbabwe  2016
# 141747          ZWE     Zimbabwe  2017
# 141748          ZWE     Zimbabwe  2018
# 141749          ZWE     Zimbabwe  2019
#
#                                        Variable  Value
# 0       Access to electricity (% of population)   24.2
# 1       Access to electricity (% of population)   24.2
# 2       Access to electricity (% of population)   24.2
# 3       Access to electricity (% of population)   24.2
# 4       Access to electricity (% of population)   24.2
# ...                                         ...    ...
# 141745                          Income1995_code    1.0
# 141746                          Income1995_code    1.0
# 141747                          Income1995_code    1.0
# 141748                          Income1995_code    1.0
# 141749                          Income1995_code    1.0
#
# [141750 rows x 5 columns]

# %% [markdown]
# ## 1) Collapsed data (1 row per country)

# %% [markdown]
# ### Pre-processing

# %%
windows = {
    3: ([1995, 1996, 1997], [2017, 2018, 2019]),
    5: ([1995, 1996, 1997, 1998, 1999], [2015, 2016, 2017, 2018, 2019]),
    7: ([1995, 1996, 1997, 1998, 1999, 2000, 2001], 
        [2013, 2014, 2015, 2016, 2017, 2018, 2019])
}

results = {}

for k, (start_years, end_years) in windows.items():

    df_k = master_data_long[
        master_data_long['Year'].isin(start_years + end_years)
    ].copy()

    pivot = df_k.pivot_table(
        index=['Country Code', 'Variable'],
        columns='Year',
        values='Value'
    )

    # Averages
    pivot['avg_start'] = pivot[start_years].mean(axis=1)
    pivot['avg_end']   = pivot[end_years].mean(axis=1)

    # Build variable-specific outcome
    pivot['value_out'] = pivot['avg_start']              # Average start years for all variables except ECI
    pivot.loc[
        pivot.index.get_level_values('Variable') == 'Economic Complexity Index', # For values assigned with ECI, replace value_out with net change 
        'value_out'
    ] = pivot['avg_end'] - pivot['avg_start']             # ECI net change

    # To wide
    df_out = pivot['value_out'].reset_index().pivot(
        index='Country Code',
        columns='Variable',
        values='value_out'
    )

    results[k] = df_out.merge(
        clusters_list,
        how='right',
        on='Country Code'
    )

# Final outputs
df_3_change_clusters = results[3]
df_5_change_clusters = results[5]
df_7_change_clusters = results[7]

# %% [markdown]
# #### NA check

# %%
df_3_change_clusters.isna().sum()
# Out:
# Country Code                                                            0
# Access to electricity (% of population)                                18
# Adjusted savings: gross savings (% of GNI)                             18
# Agriculture                                                            18
# Capital depreciation rate                                              18
# Clientelism index                                                      18
# Death rates, crude per 1000 people                                     18
# Domestic credit to private sector (% of GDP)                           18
# Economic Complexity Index                                              18
# GDP per capita (constant prices, PPP)                                  18
# Government revenue                                                     18
# Gross fixed capital formation, all, Constant prices, Percent of GDP    18
# Human capital index                                                    18
# Hydrocarbons_Dominant                                                  18
# Income1995_code                                                        19
# Industry                                                               18
# Inflation, consumer prices (annual %)                                  18
# Landlocked                                                             18
# Lending interest rate (%)                                              18
# Life expectancy at birth, total (years)                                18
# Manufacturing                                                          18
# Mineral rents (% of GDP)                                               18
# Mobile cellular subscriptions (per 100 people)                         18
# Natural gas rents (% of GDP)                                           18
# Oil rents (% of GDP)                                                   18
# Political corruption index                                             18
# Political stability — estimate                                         18
# Population                                                             18
# Precious_Metals_Dominant                                               18
# Primary net lending, General government, Percent of GDP                18
# Property rights                                                        18
# Real interest rate (%)                                                 18
# Rule of law index                                                      18
# Services                                                               18
# Share of consumption in GDP                                            18
# Share of government spending in GDP                                    18
# Share of investment in GDP                                             18
# Subsoil_Metals_Dominant                                                18
# Total natural resources rents (% of GDP)                               18
# Total_Production                                                       18
# Total_Production_Value                                                 18
# Total_Reserves                                                         18
# Total_Reserves_Value                                                   18
# Trade (% of GDP)                                                       18
# Urban population (% of total population)                               18
# Use of IMF credit (DOD, current US$)                                   18
# Country Name                                                            0
# cluster_6                                                               0
# dtype: int64

# %%
# Histogram of ECI changes
dfs = {
#    3: df_3_change_clusters,
     5: df_5_change_clusters,
#    7: df_7_change_clusters
}

for k, df in dfs.items():
    plt.figure(figsize=(7,4))
    sns.histplot(df['Economic Complexity Index'], bins=15, kde=True, color='skyblue')
    plt.title(f'ECI Absolute Changes ({k}-year averages)')
    plt.xlabel('ECI Absolute Change')
    plt.ylabel('Number of Countries')
    plt.grid(axis='y', alpha=0.3)
    plt.show()

# %%
dfs = {
#    3: df_3_change_clusters,
     5: df_5_change_clusters,
#    7: df_7_change_clusters
}

for k, df in dfs.items():

    df_sorted = df.sort_values('cluster_6').reset_index(drop=True)

    plt.figure(figsize=(10,4))

    unique_clusters = df_sorted['cluster_6'].unique()
    palette = sns.color_palette("tab10", n_colors=len(unique_clusters))
    cluster_colors = dict(zip(unique_clusters, palette))

    # Line
    plt.plot(df_sorted.index, df_sorted['Economic Complexity Index'],
             linestyle='-', color='gray', alpha=0.5)

    # Points + labels
    for cluster in unique_clusters:
        cluster_data = df_sorted[df_sorted['cluster_6'] == cluster]
        plt.scatter(cluster_data.index,
                    cluster_data['Economic Complexity Index'],
                    color=cluster_colors[cluster],
                    s=50,
                    label=f'Cluster {cluster}',
                    zorder=3)

        for i, row in cluster_data.iterrows():
            plt.text(i,
                     row['Economic Complexity Index'] + 0.04,
                     row['Country Code'],
                     ha='center',
                     va='bottom',
                     fontsize=8,
                     rotation=45)

    plt.axhline(0, color='red', linestyle='--', linewidth=1.5)
    plt.xticks([])
    plt.title(f'ECI Absolute Changes ({k}-year averages)')
    plt.ylabel('ECI Absolute Change')
    plt.grid(alpha=0.3)
    plt.legend(title='Cluster 6', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
dfs = {
#    3: df_3_change_clusters,
    5: df_5_change_clusters,
#    7: df_7_change_clusters
}

for k, df in dfs.items():
    # Create a categorical variable with 3 equally sized groups
    df_5_change_clusters['label'] = pd.qcut(
        df_5_change_clusters['Economic Complexity Index'], 
        q=3,  # split into 3 quantiles
        labels=['Not Successful', 'Mid Successful', 'Successful']
        )

    # Sort by ECI change
    df_sorted = df_5_change_clusters.sort_values('Economic Complexity Index').reset_index(drop=True)

    plt.figure(figsize=(12,4))

    # Generate a color palette based on unique clusters
    unique_clusters = df_sorted['label'].unique()
    palette = sns.color_palette("tab10", n_colors=len(unique_clusters))
    cluster_colors = {cluster: color for cluster, color in zip(unique_clusters, palette)}

    # Plot line connecting points (gray)
    plt.plot(df_sorted.index, df_sorted['Economic Complexity Index'], linestyle='-', color='gray', alpha=0.5)

    # Plot points colored by cluster and keep references for legend
    scatter_handles = []
    for cluster in unique_clusters:
        cluster_data = df_sorted[df_sorted['label'] == cluster]
        sc = plt.scatter(cluster_data.index, cluster_data['Economic Complexity Index'],
                         color=cluster_colors[cluster], s=30, label=f'{cluster}', zorder=3)
        scatter_handles.append(sc)
        # Annotate each point with country code
        for i, row in cluster_data.iterrows():
            plt.text(i, row['Economic Complexity Index'] + 0.04, row['Country Code'], 
                    ha='center', va='bottom', fontsize=5, rotation=90)

    # Remove x-axis labels
    plt.xticks([])
    # Add red dashed horizontal line at 0
    plt.axhline(y=0.0, color='red', linestyle='--', linewidth=1.5)
    plt.title(f'ECI Absolute Change ({k}-year averages)')
    plt.xlabel('')
    plt.ylabel('ECI Absolute Change')
    plt.grid(alpha=0.3)
    plt.legend(title='Label', bbox_to_anchor=(.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## LASSO

# %%
# ----------------------------
# 1. Drop rows with missing outcome
# ----------------------------
df_clean = df_5_change_clusters.dropna(subset=['Economic Complexity Index']).copy()
df_clean = df_clean.dropna(axis=1, how='all')

# ----------------------------
# 2. Separate outcome and predictors
# ----------------------------
y = df_clean['Economic Complexity Index'].values

X = df_clean.drop(columns=['Country Code', 'Country Name', 'cluster_6', 'Economic Complexity Index', 'label']).values
feature_names = df_clean.drop(columns=['Country Code', 'Country Name', 'cluster_6', 'Economic Complexity Index', 'label']).columns

# ----------------------------
# 3. Impute missing predictor values
# ----------------------------
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 4. Standardize predictors
# ----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# ----------------------------
# 5. LASSO with cross-validation
# ----------------------------
lasso_cv = LassoCV(cv=10, random_state=42, max_iter=10000)
lasso_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients (indexed by feature names, not rows!)
# ----------------------------
coef = pd.Series(lasso_cv.coef_, index=feature_names)
#print("LASSO coefficients:\n", coef)

# ----------------------------
# 7. Selected predictors (non-zero coefficients)
# ----------------------------
selected = coef[coef != 0].sort_values(key=abs, ascending=False)
#print("Selected predictors:\n", selected)

# ----------------------------
# 8. Optional: Plot
# ----------------------------
plt.figure(figsize=(8,6))
selected.plot(kind='barh')
plt.title("Selected predictors (LASSO)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# #### LASSO Robustness

# %%
# 1) Different subsamples
n_boot = 50
selected = pd.DataFrame(0, index=feature_names, columns=range(n_boot))

for b in range(n_boot):
    idx = np.random.choice(len(y), size=len(y), replace=True)
    
    X_b = X_scaled[idx]
    y_b = y[idx]

    lasso = LassoCV(cv=5, max_iter=10000, random_state=b)
    lasso.fit(X_b, y_b)

    selected.iloc[:, b] = (lasso.coef_ != 0).astype(int)

selection_freq = selected.mean(axis=1).sort_values(ascending=False)
print(selection_freq)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.961e-03, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.067e-02, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.180e-02, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.985e-02, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.384e-02, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.476e-02, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.543e-02, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.062e-01, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.121e-01, tolerance: 1.512e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.232e-03, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.876e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.978e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.585e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.883e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.003e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.012e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.592e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.027e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.719e-02, tolerance: 1.180e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.561e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.067e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.119e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.070e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.832e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.199e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.264e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.661e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.928e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.949e-03, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.411e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.520e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.528e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.501e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.464e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.424e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.382e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.340e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.298e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.257e-02, tolerance: 2.181e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.197e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.476e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.359e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.637e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.491e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.354e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.456e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.034e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.747e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.370e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.812e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.738e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.115e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.001e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.102e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.144e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.742e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.456e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.229e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.012e-03, tolerance: 1.760e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.421e-03, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.152e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.602e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.891e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.582e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.814e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.122e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.929e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.217e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.287e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.157e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.043e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.755e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.625e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.783e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.833e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.766e-02, tolerance: 1.857e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.809e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.269e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.386e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.343e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.506e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.570e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.369e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.899e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.652e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.756e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.689e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.681e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.000e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.346e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.346e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.111e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.840e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.571e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.313e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.062e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.820e-03, tolerance: 1.689e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.611e-03, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.895e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.052e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.004e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.995e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.220e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.215e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.279e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.208e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.050e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.939e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.868e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.783e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.755e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.747e-02, tolerance: 2.018e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.018e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.012e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.652e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.877e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.915e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.871e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.792e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.698e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.599e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.499e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.399e-02, tolerance: 2.246e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.538e-02, tolerance: 1.967e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.898e-02, tolerance: 1.967e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.764e-02, tolerance: 1.967e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e-01, tolerance: 1.967e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e-01, tolerance: 1.967e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.238e-01, tolerance: 1.967e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.829e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.767e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.818e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.356e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.643e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.256e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.169e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.811e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.875e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.745e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.718e-02, tolerance: 1.984e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.637e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.659e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.995e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.593e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.540e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.644e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.695e-02, tolerance: 2.109e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.703e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.312e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.950e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.947e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.647e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.648e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.162e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.187e-03, tolerance: 1.960e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# Trade (% of GDP)                                                       1.00
# Capital depreciation rate                                              0.98
# Share of government spending in GDP                                    0.90
# Hydrocarbons_Dominant                                                  0.80
# Adjusted savings: gross savings (% of GNI)                             0.78
# Landlocked                                                             0.76
# Manufacturing                                                          0.66
# Government revenue                                                     0.64
# Population                                                             0.54
# Share of investment in GDP                                             0.48
# Political stability — estimate                                         0.48
# Precious_Metals_Dominant                                               0.44
# Real interest rate (%)                                                 0.44
# Mineral rents (% of GDP)                                               0.42
# Property rights                                                        0.40
# Use of IMF credit (DOD, current US$)                                   0.40
# Natural gas rents (% of GDP)                                           0.40
# Human capital index                                                    0.38
# Gross fixed capital formation, all, Constant prices, Percent of GDP    0.32
# Death rates, crude per 1000 people                                     0.32
# Clientelism index                                                      0.32
# Mobile cellular subscriptions (per 100 people)                         0.30
# Domestic credit to private sector (% of GDP)                           0.30
# Primary net lending, General government, Percent of GDP                0.28
# Subsoil_Metals_Dominant                                                0.28
# Share of consumption in GDP                                            0.26
# GDP per capita (constant prices, PPP)                                  0.24
# Inflation, consumer prices (annual %)                                  0.24
# Oil rents (% of GDP)                                                   0.18
# Total_Production_Value                                                 0.18
# Total_Reserves                                                         0.18
# Total_Reserves_Value                                                   0.16
# Rule of law index                                                      0.16
# Services                                                               0.16
# Access to electricity (% of population)                                0.12
# Agriculture                                                            0.12
# Lending interest rate (%)                                              0.12
# Total natural resources rents (% of GDP)                               0.12
# Income1995_code                                                        0.10
# Life expectancy at birth, total (years)                                0.10
# Industry                                                               0.10
# Political corruption index                                             0.08
# Total_Production                                                       0.02
# Urban population (% of total population)                               0.02
# dtype: float64

# %% [markdown]
# ## Ridge

# %%
# ----------------------------
# 5. RIDGE with cross-validation
# ----------------------------
ridge_cv = RidgeCV(
    alphas=np.logspace(-4, 4, 100),
    cv=10
)
ridge_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients
# ----------------------------
coef = pd.Series(ridge_cv.coef_, index=feature_names)

# ----------------------------
# 7. Rank predictors by importance
# ----------------------------
ranked = coef.abs().sort_values(ascending=False)

# ----------------------------
# 8. Optional: Plot top coefficients
# ----------------------------
top_k = 20  # change if needed

plt.figure(figsize=(8, 6))
coef.loc[ranked.index[:top_k]].sort_values().plot(kind='barh')
plt.title("Top predictors (Ridge)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Single tree

# %%
# ----------------------------
# 1. Drop rows with missing outcome
# ----------------------------
df_clean = df_5_change_clusters.dropna(
    subset=['Economic Complexity Index']
).copy() # Drops rows with missing ECI

df_clean = df_clean.dropna(axis=1, how='all') # Drops all missing columns (they don't have data for the start year)

# ----------------------------
# 2. Separate outcome and predictors
# ----------------------------
y = df_clean['Economic Complexity Index'].values

X_df = df_clean.drop(
    columns=['Country Code', 'Country Name', 'cluster_6',
             'Economic Complexity Index', 'label'],
    errors='ignore'
)

feature_names = X_df.columns
X = X_df.values

# ----------------------------
# 3. Impute missing predictor values
# ----------------------------
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 4. Fit simple decision tree
# ----------------------------
tree_simple = DecisionTreeRegressor(
    max_depth=3,          # shallow & interpretable
    min_samples_leaf=5,
    random_state=42
)

tree_simple.fit(X_imputed, y)

# ----------------------------
# 5. Visualize simple tree
# ----------------------------
plt.figure(figsize=(22, 12))
plot_tree(
    tree_simple,
    feature_names=feature_names,
    filled=True,
    rounded=True,
    fontsize=10
)

plt.title("Simple Decision Tree (Exploratory)")
plt.show()

# %% [markdown]
# ## Random Forest

# %%
# ----------------------------
# 6. Random Forest (3 levels)
# ----------------------------
rf = RandomForestRegressor(
    n_estimators=1000,
    max_depth=4,          # <-- 3 levels
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_imputed, y)

# ----------------------------
# 7. Feature importance
# ----------------------------
importance = pd.Series(
    rf.feature_importances_,
    index=feature_names
).sort_values(ascending=False)

#print("Random Forest feature importance:\n", importance)

# ----------------------------
# 7. Plot importance
# ----------------------------
plt.figure(figsize=(16,8))
importance.plot(kind='barh')
plt.title("Feature importance (Random Forest, depth = 3)")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Random Forest Robustness

# %%
# Out of bag (OOB): it's like R2 for RF
rf_oob = RandomForestRegressor(
    n_estimators=1000,
    max_depth=4,
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1,
    oob_score=True
)

rf_oob.fit(X_imputed, y)

print("OOB R²:", rf_oob.oob_score_)
# Out:
# OOB R²: 0.14047435693199384

# %% [markdown]
# ## 2) Panel data (25 rows per country)

# %% [markdown]
# ## Lasso

# %%
## Lagged variables
master_data = master_data.sort_values(['Country Code', 'Country Name', 'Year'])

# List all columns to create lagged versions for (exclude 'country' and 'year')
vars_to_lag = [col for col in master_data.columns if col not in ['Country Code', 'Country Name',  'Year', 'Income1995_code']]

# Create lagged variables by 5 periods
lag = 5
for var in vars_to_lag:
    master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)

# Drop rows with NaNs created by lagging
master_data = master_data.dropna()

master_data
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29088\1129341667.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)
# 0

# %%
# ----------------------------
# 1. Drop rows with missing outcome
# ----------------------------
df_clean = master_data.dropna(subset=['Economic Complexity Index']).copy()
df_clean = df_clean.dropna(axis=1, how='all')

# ----------------------------
# 2. Separate outcome and predictors
# ----------------------------
y = df_clean['Economic Complexity Index'].values

X = df_clean.drop(columns=['Country Code', 'Country Name', 'Economic Complexity Index', 'Year', 'Income1995_code']).values
feature_names = df_clean.drop(columns=['Country Code', 'Country Name', 'Economic Complexity Index', 'Year', 'Income1995_code']).columns

# ----------------------------
# 3. Impute missing predictor values
# ----------------------------
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 4. Standardize predictors
# ----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# ----------------------------
# 5. LASSO with cross-validation
# ----------------------------
lasso_cv = LassoCV(cv=10, random_state=42, max_iter=10000)
lasso_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients (indexed by feature names, not rows!)
# ----------------------------
coef = pd.Series(lasso_cv.coef_, index=feature_names)
#print("LASSO coefficients:\n", coef)

# ----------------------------
# 7. Selected predictors (non-zero coefficients)
# ----------------------------
selected = coef[coef != 0].sort_values(key=abs, ascending=False)
#print("Selected predictors:\n", selected)

# ----------------------------
# 8. Optional: Plot
# ----------------------------
plt.figure(figsize=(8,6))
selected.plot(kind='barh')
plt.title("Selected predictors (LASSO)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Ridge

# %%
# ----------------------------
# 5. RIDGE with cross-validation
# ----------------------------
ridge_cv = RidgeCV(
    alphas=np.logspace(-4, 4, 100),
    cv=10
)
ridge_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients
# ----------------------------
coef = pd.Series(ridge_cv.coef_, index=feature_names)

# ----------------------------
# 7. Rank predictors by importance
# ----------------------------
ranked = coef.abs().sort_values(ascending=False)

# ----------------------------
# 8. Optional: Plot top coefficients
# ----------------------------
top_k = 20  # change if needed

plt.figure(figsize=(8, 6))
coef.loc[ranked.index[:top_k]].sort_values().plot(kind='barh')
plt.title("Top predictors (Ridge)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Random Forest

# %%
# ----------------------------
# 6. Random Forest (3 levels)
# ----------------------------
rf = RandomForestRegressor(
    n_estimators=1000,
    max_depth=4,          # <-- 3 levels
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_imputed, y)

# ----------------------------
# 7. Feature importance
# ----------------------------
importance = pd.Series(
    rf.feature_importances_,
    index=feature_names
).sort_values(ascending=False)

# Keep only top 10 variables
importance_top10 = importance.head(15)

# ----------------------------
# 8. Plot importance (top 10)
# ----------------------------
plt.figure(figsize=(10, 6))
importance_top10.plot(kind='barh')
plt.title("Top 10 Feature Importance (Random Forest, depth = 4)")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
