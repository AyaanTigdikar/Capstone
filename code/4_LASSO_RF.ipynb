# %%
# Data Manipulation
import pandas as pd
import numpy as np
import requests
from io import StringIO

# Visualization (Static)
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization (Interactive)
import plotly.express as px

# Machine Learning & Clustering
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeClassifier
# Packages for visualizing the tree
from sklearn.metrics import accuracy_score, f1_score, brier_score_loss
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
# Code for the bootstrap resample
from sklearn.utils import resample
from sklearn.tree import plot_tree

# %% [markdown]
# # Import Data

# %%
 # 1) All variables and countries from the master data
master_data = (pd.read_csv("https://raw.githubusercontent.com/AyaanTigdikar/Capstone/refs/heads/main/MASTER/Master.csv")
               .drop(columns=['Unnamed: 0'], errors='ignore'))


nr = (pd.read_csv("https://raw.githubusercontent.com/AyaanTigdikar/Capstone/refs/heads/main/MASTER/NaturalResource.csv")
               .drop(columns=['Unnamed: 0'], errors='ignore'))


# 2) Clusters list from Leo
clusters_list = pd.read_csv('https://raw.githubusercontent.com/AyaanTigdikar/Capstone/refs/heads/main/workingdata/clusters_list.csv')

# %%
# Suppose your string column is 'Income1995'
# 1. Ensure it’s clean (strip spaces, handle missing values)
master_data['Income1995'] = master_data['Income1995'].astype(str).str.strip()
master_data['Income1995'].replace({'': pd.NA, 'nan': pd.NA}, inplace=True)

# 2. Convert to categorical
master_data['Income1995'] = master_data['Income1995'].astype('category')

# 3. Encode as integer codesx
master_data['Income1995_code'] = master_data['Income1995'].cat.codes

# Define mapping
income_mapping = {
    'Low-income countries': 1,
    'Lower-middle-income countries': 2,
    'Upper-middle-income countries': 3,
    'High-income countries': 4
}

# Apply mapping to create new numeric column
master_data['Income1995_code'] = master_data['Income1995'].map(income_mapping)

master_data = master_data.drop(columns='Income1995')

# %%
# Note: I am replacing the previous master data long with Ayaan's master data
master_data_long = master_data.melt(
    id_vars=['Country Code', 'Country Name', 'Year'],
    var_name= 'Variable',
    value_name='Value'
)

master_data_long
# Out:
#        Country Code Country Name  Year  \
# 0               AGO       Angola  1995
# 1               AGO       Angola  1996
# 2               AGO       Angola  1997
# 3               AGO       Angola  1998
# 4               AGO       Angola  1999
# ...             ...          ...   ...
# 141745          ZWE     Zimbabwe  2015
# 141746          ZWE     Zimbabwe  2016
# 141747          ZWE     Zimbabwe  2017
# 141748          ZWE     Zimbabwe  2018
# 141749          ZWE     Zimbabwe  2019
#
#                                        Variable  Value
# 0       Access to electricity (% of population)   24.2
# 1       Access to electricity (% of population)   24.2
# 2       Access to electricity (% of population)   24.2
# 3       Access to electricity (% of population)   24.2
# 4       Access to electricity (% of population)   24.2
# ...                                         ...    ...
# 141745                          Income1995_code    1.0
# 141746                          Income1995_code    1.0
# 141747                          Income1995_code    1.0
# 141748                          Income1995_code    1.0
# 141749                          Income1995_code    1.0
#
# [141750 rows x 5 columns]

# %% [markdown]
# ## 1) Collapsed data (1 row per country only)

# %% [markdown]
# ### Pre-processing

# %%
windows = {
    3: ([1995, 1996, 1997], [2017, 2018, 2019]),
    5: ([1995, 1996, 1997, 1998, 1999], [2015, 2016, 2017, 2018, 2019]),
    7: ([1995, 1996, 1997, 1998, 1999, 2000, 2001], 
        [2013, 2014, 2015, 2016, 2017, 2018, 2019])
}

results = {}

for k, (start_years, end_years) in windows.items():

    df_k = master_data_long[
        master_data_long['Year'].isin(start_years + end_years)
    ].copy()

    pivot = df_k.pivot_table(
        index=['Country Code', 'Variable'],
        columns='Year',
        values='Value'
    )

    # Averages
    pivot['avg_start'] = pivot[start_years].mean(axis=1)
    pivot['avg_end']   = pivot[end_years].mean(axis=1)

    # Build variable-specific outcome
    pivot['value_out'] = pivot['avg_start']              # Average start years for all variables except ECI
    pivot.loc[
        pivot.index.get_level_values('Variable') == 'Economic Complexity Index', # For values assigned with ECI, replace value_out with net change 
        'value_out'
    ] = pivot['avg_end'] - pivot['avg_start']             # ECI net change

    # To wide
    df_out = pivot['value_out'].reset_index().pivot(
        index='Country Code',
        columns='Variable',
        values='value_out'
    )

    results[k] = df_out.merge(
        clusters_list,
        how='right',
        on='Country Code'
    )

# Final outputs
df_3_change_clusters = results[3]
df_5_change_clusters = results[5]
df_7_change_clusters = results[7]

# %% [markdown]
# #### NA check

# %%
df_3_change_clusters.isna().sum()
# Out:
# Country Code                                                            0
# Access to electricity (% of population)                                18
# Adjusted savings: gross savings (% of GNI)                             18
# Agriculture                                                            18
# Capital depreciation rate                                              18
# Clientelism index                                                      18
# Death rates, crude per 1000 people                                     18
# Domestic credit to private sector (% of GDP)                           18
# Economic Complexity Index                                              18
# GDP per capita (constant prices, PPP)                                  18
# Government revenue                                                     18
# Gross fixed capital formation, all, Constant prices, Percent of GDP    18
# Human capital index                                                    18
# Hydrocarbons_Dominant                                                  18
# Income1995_code                                                        19
# Industry                                                               18
# Inflation, consumer prices (annual %)                                  18
# Landlocked                                                             18
# Lending interest rate (%)                                              18
# Life expectancy at birth, total (years)                                18
# Manufacturing                                                          18
# Mineral rents (% of GDP)                                               18
# Mobile cellular subscriptions (per 100 people)                         18
# Natural gas rents (% of GDP)                                           18
# Oil rents (% of GDP)                                                   18
# Political corruption index                                             18
# Political stability — estimate                                         18
# Population                                                             18
# Precious_Metals_Dominant                                               18
# Primary net lending, General government, Percent of GDP                18
# Property rights                                                        18
# Real interest rate (%)                                                 18
# Rule of law index                                                      18
# Services                                                               18
# Share of consumption in GDP                                            18
# Share of government spending in GDP                                    18
# Share of investment in GDP                                             18
# Subsoil_Metals_Dominant                                                18
# Total natural resources rents (% of GDP)                               18
# Total_Production                                                       18
# Total_Production_Value                                                 18
# Total_Reserves                                                         18
# Total_Reserves_Value                                                   18
# Trade (% of GDP)                                                       18
# Urban population (% of total population)                               18
# Use of IMF credit (DOD, current US$)                                   18
# Country Name                                                            0
# cluster_6                                                               0
# dtype: int64

# %%
# Histogram of ECI changes
dfs = {
    3: df_3_change_clusters,
    5: df_5_change_clusters,
    7: df_7_change_clusters
}

for k, df in dfs.items():
    plt.figure(figsize=(7,4))
    sns.histplot(df['Economic Complexity Index'], bins=15, kde=True, color='skyblue')
    plt.title(f'ECI Absolute Changes ({k}-year averages)')
    plt.xlabel('ECI Absolute Change')
    plt.ylabel('Number of Countries')
    plt.grid(axis='y', alpha=0.3)
    plt.show()

# %%
dfs = {
    3: df_3_change_clusters,
    5: df_5_change_clusters,
    7: df_7_change_clusters
}

for k, df in dfs.items():

    df_sorted = df.sort_values('cluster_6').reset_index(drop=True)

    plt.figure(figsize=(10,4))

    unique_clusters = df_sorted['cluster_6'].unique()
    palette = sns.color_palette("tab10", n_colors=len(unique_clusters))
    cluster_colors = dict(zip(unique_clusters, palette))

    # Line
    plt.plot(df_sorted.index, df_sorted['Economic Complexity Index'],
             linestyle='-', color='gray', alpha=0.5)

    # Points + labels
    for cluster in unique_clusters:
        cluster_data = df_sorted[df_sorted['cluster_6'] == cluster]
        plt.scatter(cluster_data.index,
                    cluster_data['Economic Complexity Index'],
                    color=cluster_colors[cluster],
                    s=50,
                    label=f'Cluster {cluster}',
                    zorder=3)

        for i, row in cluster_data.iterrows():
            plt.text(i,
                     row['Economic Complexity Index'] + 0.04,
                     row['Country Code'],
                     ha='center',
                     va='bottom',
                     fontsize=8,
                     rotation=45)

    plt.axhline(0, color='red', linestyle='--', linewidth=1.5)
    plt.xticks([])
    plt.title(f'ECI Absolute Changes ({k}-year averages)')
    plt.ylabel('ECI Absolute Change')
    plt.grid(alpha=0.3)
    plt.legend(title='Cluster 6', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
dfs = {
    3: df_3_change_clusters,
    5: df_5_change_clusters,
    7: df_7_change_clusters
}

for k, df in dfs.items():
    # Create a categorical variable with 3 equally sized groups
    df_5_change_clusters['label'] = pd.qcut(
        df_5_change_clusters['Economic Complexity Index'], 
        q=3,  # split into 3 quantiles
        labels=['Not Successful', 'Mid Successful', 'Successful']
        )

    # Sort by ECI change
    df_sorted = df_5_change_clusters.sort_values('Economic Complexity Index').reset_index(drop=True)

    plt.figure(figsize=(12,4))

    # Generate a color palette based on unique clusters
    unique_clusters = df_sorted['label'].unique()
    palette = sns.color_palette("tab10", n_colors=len(unique_clusters))
    cluster_colors = {cluster: color for cluster, color in zip(unique_clusters, palette)}

    # Plot line connecting points (gray)
    plt.plot(df_sorted.index, df_sorted['Economic Complexity Index'], linestyle='-', color='gray', alpha=0.5)

    # Plot points colored by cluster and keep references for legend
    scatter_handles = []
    for cluster in unique_clusters:
        cluster_data = df_sorted[df_sorted['label'] == cluster]
        sc = plt.scatter(cluster_data.index, cluster_data['Economic Complexity Index'],
                         color=cluster_colors[cluster], s=30, label=f'{cluster}', zorder=3)
        scatter_handles.append(sc)
        # Annotate each point with country code
        for i, row in cluster_data.iterrows():
            plt.text(i, row['Economic Complexity Index'] + 0.04, row['Country Code'], 
                    ha='center', va='bottom', fontsize=5, rotation=90)

    # Remove x-axis labels
    plt.xticks([])
    # Add red dashed horizontal line at 0
    plt.axhline(y=0.0, color='red', linestyle='--', linewidth=1.5)
    plt.title(f'ECI Absolute Change ({k}-year averages)')
    plt.xlabel('')
    plt.ylabel('ECI Absolute Change')
    plt.grid(alpha=0.3)
    plt.legend(title='Label', bbox_to_anchor=(.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## LASSO

# %%
# ----------------------------
# 1. Drop rows with missing outcome
# ----------------------------
df_clean = df_5_change_clusters.dropna(subset=['Economic Complexity Index']).copy()
df_clean = df_clean.dropna(axis=1, how='all')

# ----------------------------
# 2. Separate outcome and predictors
# ----------------------------
y = df_clean['Economic Complexity Index'].values

X = df_clean.drop(columns=['Country Code', 'Country Name', 'cluster_6', 'Economic Complexity Index', 'label']).values
feature_names = df_clean.drop(columns=['Country Code', 'Country Name', 'cluster_6', 'Economic Complexity Index', 'label']).columns

# ----------------------------
# 3. Impute missing predictor values
# ----------------------------
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 4. Standardize predictors
# ----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# ----------------------------
# 5. LASSO with cross-validation
# ----------------------------
lasso_cv = LassoCV(cv=10, random_state=42, max_iter=10000)
lasso_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients (indexed by feature names, not rows!)
# ----------------------------
coef = pd.Series(lasso_cv.coef_, index=feature_names)
#print("LASSO coefficients:\n", coef)

# ----------------------------
# 7. Selected predictors (non-zero coefficients)
# ----------------------------
selected = coef[coef != 0].sort_values(key=abs, ascending=False)
#print("Selected predictors:\n", selected)

# ----------------------------
# 8. Optional: Plot
# ----------------------------
plt.figure(figsize=(8,6))
selected.plot(kind='barh')
plt.title("Selected predictors (LASSO)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# #### LASSO Robustness

# %%
# 1) Different subsamples
n_boot = 50
selected = pd.DataFrame(0, index=feature_names, columns=range(n_boot))

for b in range(n_boot):
    idx = np.random.choice(len(y), size=len(y), replace=True)
    
    X_b = X_scaled[idx]
    y_b = y[idx]

    lasso = LassoCV(cv=5, max_iter=10000, random_state=b)
    lasso.fit(X_b, y_b)

    selected.iloc[:, b] = (lasso.coef_ != 0).astype(int)

selection_freq = selected.mean(axis=1).sort_values(ascending=False)
print(selection_freq)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.527e-03, tolerance: 1.803e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.056e-03, tolerance: 1.803e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.429e-03, tolerance: 1.803e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.489e-03, tolerance: 1.729e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.560e-02, tolerance: 1.729e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.642e-02, tolerance: 1.729e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.892e-03, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.775e-02, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.441e-02, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.438e-02, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.984e-02, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.249e-02, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.351e-02, tolerance: 1.499e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.220e-03, tolerance: 1.682e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.846e-03, tolerance: 1.780e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.079e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.810e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.122e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.388e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.391e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.318e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.047e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.906e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.797e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.687e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.572e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.455e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.338e-03, tolerance: 1.500e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.977e-03, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.422e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.617e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.066e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.254e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.303e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.297e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.266e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.224e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.120e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.885e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.633e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.759e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.654e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.586e-02, tolerance: 1.514e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.666e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.854e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.308e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.553e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.454e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.253e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.910e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.455e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.617e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.466e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.244e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.006e-03, tolerance: 1.532e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.869e-03, tolerance: 1.629e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.768e-03, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.441e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.870e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.591e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.830e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.910e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e-02, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.536e-03, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.629e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.916e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.267e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.163e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.754e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.308e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.073e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.598e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.020e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.431e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.604e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.586e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.230e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.899e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.131e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.402e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.426e-02, tolerance: 1.567e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.540e-03, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.399e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.215e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.150e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.880e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.955e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.690e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.252e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.931e-02, tolerance: 1.480e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.252e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.132e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.220e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.727e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.838e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.841e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.118e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.165e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.150e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.113e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.064e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.008e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.952e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.894e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.831e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.767e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.391e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.158e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.191e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.447e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.455e-02, tolerance: 1.547e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.377e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.949e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.350e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.568e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.719e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.439e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.504e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.591e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.598e-02, tolerance: 2.001e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.291e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.458e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.525e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.314e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.064e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.810e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.558e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.176e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.330e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.048e-03, tolerance: 2.257e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.342e-03, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.469e-03, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.580e-03, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.482e-03, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.660e-03, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.624e-03, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.085e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.100e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.230e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.229e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.199e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.163e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.125e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.086e-02, tolerance: 2.340e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# Trade (% of GDP)                                                       1.00
# Capital depreciation rate                                              0.98
# Adjusted savings: gross savings (% of GNI)                             0.90
# Hydrocarbons_Dominant                                                  0.82
# Share of government spending in GDP                                    0.80
# Landlocked                                                             0.78
# Government revenue                                                     0.66
# Manufacturing                                                          0.60
# Share of investment in GDP                                             0.56
# Real interest rate (%)                                                 0.56
# Political stability — estimate                                         0.54
# Human capital index                                                    0.48
# Population                                                             0.46
# Precious_Metals_Dominant                                               0.44
# Mineral rents (% of GDP)                                               0.42
# Clientelism index                                                      0.32
# Death rates, crude per 1000 people                                     0.30
# Natural gas rents (% of GDP)                                           0.28
# Mobile cellular subscriptions (per 100 people)                         0.28
# Property rights                                                        0.28
# Services                                                               0.26
# Inflation, consumer prices (annual %)                                  0.26
# Subsoil_Metals_Dominant                                                0.26
# Total_Production_Value                                                 0.26
# Gross fixed capital formation, all, Constant prices, Percent of GDP    0.26
# Use of IMF credit (DOD, current US$)                                   0.24
# Lending interest rate (%)                                              0.22
# Domestic credit to private sector (% of GDP)                           0.22
# Rule of law index                                                      0.22
# Total_Reserves_Value                                                   0.20
# Primary net lending, General government, Percent of GDP                0.20
# Agriculture                                                            0.18
# Industry                                                               0.18
# GDP per capita (constant prices, PPP)                                  0.16
# Total_Reserves                                                         0.16
# Share of consumption in GDP                                            0.16
# Total natural resources rents (% of GDP)                               0.14
# Oil rents (% of GDP)                                                   0.12
# Political corruption index                                             0.10
# Access to electricity (% of population)                                0.08
# Urban population (% of total population)                               0.08
# Life expectancy at birth, total (years)                                0.08
# Income1995_code                                                        0.04
# Total_Production                                                       0.04
# dtype: float64
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.417e-03, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.224e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.826e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.444e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.928e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.113e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.159e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:701: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.142e-02, tolerance: 2.312e-03
#   model = cd_fast.enet_coordinate_descent_gram(

# %% [markdown]
# ## Ridge

# %%
# ----------------------------
# 5. RIDGE with cross-validation
# ----------------------------
ridge_cv = RidgeCV(
    alphas=np.logspace(-4, 4, 100),
    cv=10
)
ridge_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients
# ----------------------------
coef = pd.Series(ridge_cv.coef_, index=feature_names)

# ----------------------------
# 7. Rank predictors by importance
# ----------------------------
ranked = coef.abs().sort_values(ascending=False)

# ----------------------------
# 8. Optional: Plot top coefficients
# ----------------------------
top_k = 20  # change if needed

plt.figure(figsize=(8, 6))
coef.loc[ranked.index[:top_k]].sort_values().plot(kind='barh')
plt.title("Top predictors (Ridge)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Single tree

# %%
# ----------------------------
# 1. Drop rows with missing outcome
# ----------------------------
df_clean = df_5_change_clusters.dropna(
    subset=['Economic Complexity Index']
).copy() # Drops rows with missing ECI

df_clean = df_clean.dropna(axis=1, how='all') # Drops all missing columns (they don't have data for the start year)

# ----------------------------
# 2. Separate outcome and predictors
# ----------------------------
y = df_clean['Economic Complexity Index'].values

X_df = df_clean.drop(
    columns=['Country Code', 'Country Name', 'cluster_6',
             'Economic Complexity Index', 'label'],
    errors='ignore'
)

feature_names = X_df.columns
X = X_df.values

# ----------------------------
# 3. Impute missing predictor values
# ----------------------------
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 4. Fit simple decision tree
# ----------------------------
tree_simple = DecisionTreeRegressor(
    max_depth=3,          # shallow & interpretable
    min_samples_leaf=5,
    random_state=42
)

tree_simple.fit(X_imputed, y)

# ----------------------------
# 5. Visualize simple tree
# ----------------------------
plt.figure(figsize=(22, 12))
plot_tree(
    tree_simple,
    feature_names=feature_names,
    filled=True,
    rounded=True,
    fontsize=10
)

plt.title("Simple Decision Tree (Exploratory)")
plt.show()

# %% [markdown]
# ## Random Forest

# %%
# ----------------------------
# 6. Random Forest (3 levels)
# ----------------------------
rf = RandomForestRegressor(
    n_estimators=1000,
    max_depth=4,          # <-- 3 levels
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_imputed, y)

# ----------------------------
# 7. Feature importance
# ----------------------------
importance = pd.Series(
    rf.feature_importances_,
    index=feature_names
).sort_values(ascending=False)

#print("Random Forest feature importance:\n", importance)

# ----------------------------
# 7. Plot importance
# ----------------------------
plt.figure(figsize=(16,8))
importance.plot(kind='barh')
plt.title("Feature importance (Random Forest, depth = 3)")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Random Forest Robustness

# %%
# Out of bag (OOB): it's like R2 for RF
rf_oob = RandomForestRegressor(
    n_estimators=1000,
    max_depth=4,
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1,
    oob_score=True
)

rf_oob.fit(X_imputed, y)

print("OOB R²:", rf_oob.oob_score_)
# Out:
# OOB R²: 0.14047435693199384

# %% [markdown]
# ## 2) Panel data (25 rows per country)

# %%
master_data
# Out:
#      Country Code Country Name  Year  Access to electricity (% of population)  \
# 0             AGO       Angola  1995                                     24.2
# 1             AGO       Angola  1996                                     24.2
# 2             AGO       Angola  1997                                     24.2
# 3             AGO       Angola  1998                                     24.2
# 4             AGO       Angola  1999                                     24.2
# ...           ...          ...   ...                                      ...
# 3145          ZWE     Zimbabwe  2015                                     33.7
# 3146          ZWE     Zimbabwe  2016                                     42.5
# 3147          ZWE     Zimbabwe  2017                                     44.0
# 3148          ZWE     Zimbabwe  2018                                     45.4
# 3149          ZWE     Zimbabwe  2019                                     46.7
#
#       Adjusted savings: gross savings (% of GNI)  Agriculture  \
# 0                                      48.055414     9.386791
# 1                                      48.055414     9.386791
# 2                                      48.055414     9.386791
# 3                                      48.055414     9.386791
# 4                                      48.055414     9.386791
# ...                                          ...          ...
# 3145                                  -11.438012     8.284831
# 3146                                   -5.670411     7.873585
# 3147                                   -3.024929     7.247882
# 3148                                   14.220834     7.319201
# 3149                                   20.555456    22.705652
#
#       Capital depreciation rate  Clientelism index  \
# 0                      0.035367              0.840
# 1                      0.038398              0.840
# 2                      0.040405              0.840
# 3                      0.040825              0.840
# 4                      0.041406              0.840
# ...                         ...                ...
# 3145                   0.054977              0.642
# 3146                   0.056414              0.656
# 3147                   0.057745              0.642
# 3148                   0.059023              0.656
# 3149                   0.059923              0.685
#
#       Death rates, crude per 1000 people  \
# 0                                 18.700
# 1                                 18.445
# 2                                 18.184
# 3                                 18.925
# 4                                 18.518
# ...                                  ...
# 3145                               9.180
# 3146                               8.816
# 3147                               8.587
# 3148                               8.321
# 3149                               8.281
#
#       Domestic credit to private sector (% of GDP)  ...  \
# 0                                        22.274928  ...
# 1                                        22.274928  ...
# 2                                        22.274928  ...
# 3                                        22.274928  ...
# 4                                        22.274928  ...
# ...                                            ...  ...
# 3145                                     18.315744  ...
# 3146                                     17.098496  ...
# 3147                                      5.810054  ...
# 3148                                      5.830267  ...
# 3149                                      3.428022  ...
#
#       Use of IMF credit (DOD, current US$)  Total_Production  Total_Reserves  \
# 0                                      0.0      6.328546e+05          3125.0
# 1                                      0.0      7.159761e+05          3695.0
# 2                                      0.0      7.410000e+05          3900.0
# 3                                      0.0      7.308493e+05          4030.0
# 4                              374707057.4      7.450603e+05          5050.0
# ...                                    ...               ...             ...
# 3145                           463752752.4      4.345331e+06             0.0
# 3146                           455165191.5      2.711844e+06             0.0
# 3147                           482184792.8      2.937664e+06             0.0
# 3148                           470895600.2      3.358478e+06             0.0
# 3149                           468198468.7      2.636942e+06             0.0
#
#       Total_Production_Value  Total_Reserves_Value  Hydrocarbons_Dominant  \
# 0               1.253085e+07          61876.613480                      1
# 1               1.614997e+07          83346.553264                      1
# 2               1.480903e+07          77942.237484                      1
# 3               9.293232e+06          51244.115764                      1
# 4               1.284780e+07          87082.036358                      1
# ...                      ...                   ...                    ...
# 3145            6.811226e+08              0.000000                      0
# 3146            7.456858e+08              0.000000                      0
# 3147            8.136642e+08              0.000000                      0
# 3148            1.146441e+09              0.000000                      0
# 3149            9.773953e+08              0.000000                      0
#
#       Subsoil_Metals_Dominant  Precious_Metals_Dominant  Population  \
# 0                           0                         0    13699778
# 1                           0                         0    14170973
# 2                           0                         0    14660413
# 3                           0                         0    15159370
# 4                           0                         0    15667235
# ...                       ...                       ...         ...
# 3145                        0                         1    14399013
# 3146                        0                         1    14600294
# 3147                        0                         1    14812482
# 3148                        0                         1    15034452
# 3149                        0                         1    15271368
#
#       Income1995_code
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 3145                1
# 3146                1
# 3147                1
# 3148                1
# 3149                1
#
# [3150 rows x 48 columns]

# %% [markdown]
# ## Lasso

# %%
master_data
# Out:
#      Country Code Country Name  Year  Access to electricity (% of population)  \
# 0             AGO       Angola  1995                                     24.2
# 1             AGO       Angola  1996                                     24.2
# 2             AGO       Angola  1997                                     24.2
# 3             AGO       Angola  1998                                     24.2
# 4             AGO       Angola  1999                                     24.2
# ...           ...          ...   ...                                      ...
# 3145          ZWE     Zimbabwe  2015                                     33.7
# 3146          ZWE     Zimbabwe  2016                                     42.5
# 3147          ZWE     Zimbabwe  2017                                     44.0
# 3148          ZWE     Zimbabwe  2018                                     45.4
# 3149          ZWE     Zimbabwe  2019                                     46.7
#
#       Adjusted savings: gross savings (% of GNI)  Agriculture  \
# 0                                      48.055414     9.386791
# 1                                      48.055414     9.386791
# 2                                      48.055414     9.386791
# 3                                      48.055414     9.386791
# 4                                      48.055414     9.386791
# ...                                          ...          ...
# 3145                                  -11.438012     8.284831
# 3146                                   -5.670411     7.873585
# 3147                                   -3.024929     7.247882
# 3148                                   14.220834     7.319201
# 3149                                   20.555456    22.705652
#
#       Capital depreciation rate  Clientelism index  \
# 0                      0.035367              0.840
# 1                      0.038398              0.840
# 2                      0.040405              0.840
# 3                      0.040825              0.840
# 4                      0.041406              0.840
# ...                         ...                ...
# 3145                   0.054977              0.642
# 3146                   0.056414              0.656
# 3147                   0.057745              0.642
# 3148                   0.059023              0.656
# 3149                   0.059923              0.685
#
#       Death rates, crude per 1000 people  \
# 0                                 18.700
# 1                                 18.445
# 2                                 18.184
# 3                                 18.925
# 4                                 18.518
# ...                                  ...
# 3145                               9.180
# 3146                               8.816
# 3147                               8.587
# 3148                               8.321
# 3149                               8.281
#
#       Domestic credit to private sector (% of GDP)  ...  \
# 0                                        22.274928  ...
# 1                                        22.274928  ...
# 2                                        22.274928  ...
# 3                                        22.274928  ...
# 4                                        22.274928  ...
# ...                                            ...  ...
# 3145                                     18.315744  ...
# 3146                                     17.098496  ...
# 3147                                      5.810054  ...
# 3148                                      5.830267  ...
# 3149                                      3.428022  ...
#
#       Use of IMF credit (DOD, current US$)  Total_Production  Total_Reserves  \
# 0                                      0.0      6.328546e+05          3125.0
# 1                                      0.0      7.159761e+05          3695.0
# 2                                      0.0      7.410000e+05          3900.0
# 3                                      0.0      7.308493e+05          4030.0
# 4                              374707057.4      7.450603e+05          5050.0
# ...                                    ...               ...             ...
# 3145                           463752752.4      4.345331e+06             0.0
# 3146                           455165191.5      2.711844e+06             0.0
# 3147                           482184792.8      2.937664e+06             0.0
# 3148                           470895600.2      3.358478e+06             0.0
# 3149                           468198468.7      2.636942e+06             0.0
#
#       Total_Production_Value  Total_Reserves_Value  Hydrocarbons_Dominant  \
# 0               1.253085e+07          61876.613480                      1
# 1               1.614997e+07          83346.553264                      1
# 2               1.480903e+07          77942.237484                      1
# 3               9.293232e+06          51244.115764                      1
# 4               1.284780e+07          87082.036358                      1
# ...                      ...                   ...                    ...
# 3145            6.811226e+08              0.000000                      0
# 3146            7.456858e+08              0.000000                      0
# 3147            8.136642e+08              0.000000                      0
# 3148            1.146441e+09              0.000000                      0
# 3149            9.773953e+08              0.000000                      0
#
#       Subsoil_Metals_Dominant  Precious_Metals_Dominant  Population  \
# 0                           0                         0    13699778
# 1                           0                         0    14170973
# 2                           0                         0    14660413
# 3                           0                         0    15159370
# 4                           0                         0    15667235
# ...                       ...                       ...         ...
# 3145                        0                         1    14399013
# 3146                        0                         1    14600294
# 3147                        0                         1    14812482
# 3148                        0                         1    15034452
# 3149                        0                         1    15271368
#
#       Income1995_code
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 3145                1
# 3146                1
# 3147                1
# 3148                1
# 3149                1
#
# [3150 rows x 48 columns]

# %%
## Lagged variables
master_data = master_data.sort_values(['Country Code', 'Country Name', 'Year'])

# List all columns to create lagged versions for (exclude 'country' and 'year')
vars_to_lag = [col for col in master_data.columns if col not in ['Country Code', 'Country Name',  'Year', 'Income1995_code']]

# Create lagged variables by 5 periods
lag = 5
for var in vars_to_lag:
    master_data[f'{var}_L{lag}'] = master_data.groupby('Country Code')[var].shift(lag)

# Drop rows with NaNs created by lagging
master_data = master_data.dropna()

master_data
# Out:
#      Country Code Country Name  Year  Access to electricity (% of population)  \
# 5             AGO       Angola  2000                                     24.2
# 6             AGO       Angola  2001                                     20.0
# 7             AGO       Angola  2002                                     26.3
# 8             AGO       Angola  2003                                     27.4
# 9             AGO       Angola  2004                                     28.4
# ...           ...          ...   ...                                      ...
# 3145          ZWE     Zimbabwe  2015                                     33.7
# 3146          ZWE     Zimbabwe  2016                                     42.5
# 3147          ZWE     Zimbabwe  2017                                     44.0
# 3148          ZWE     Zimbabwe  2018                                     45.4
# 3149          ZWE     Zimbabwe  2019                                     46.7
#
#       Adjusted savings: gross savings (% of GNI)  Agriculture  \
# 5                                      48.055414     9.386791
# 6                                      17.545064     9.386791
# 7                                      32.334723     9.386791
# 8                                      28.851907    10.000077
# 9                                      37.512899    10.363591
# ...                                          ...          ...
# 3145                                  -11.438012     8.284831
# 3146                                   -5.670411     7.873585
# 3147                                   -3.024929     7.247882
# 3148                                   14.220834     7.319201
# 3149                                   20.555456    22.705652
#
#       Capital depreciation rate  Clientelism index  \
# 5                      0.041457              0.796
# 6                      0.041017              0.796
# 7                      0.040836              0.723
# 8                      0.040989              0.717
# 9                      0.041629              0.717
# ...                         ...                ...
# 3145                   0.054977              0.642
# 3146                   0.056414              0.656
# 3147                   0.057745              0.642
# 3148                   0.059023              0.656
# 3149                   0.059923              0.685
#
#       Death rates, crude per 1000 people  \
# 5                                 18.080
# 6                                 17.606
# 7                                 17.071
# 8                                 15.559
# 9                                 14.958
# ...                                  ...
# 3145                               9.180
# 3146                               8.816
# 3147                               8.587
# 3148                               8.321
# 3149                               8.281
#
#       Domestic credit to private sector (% of GDP)  ...  \
# 5                                        22.274928  ...
# 6                                        22.274928  ...
# 7                                        22.274928  ...
# 8                                        22.274928  ...
# 9                                        22.274928  ...
# ...                                            ...  ...
# 3145                                     18.315744  ...
# 3146                                     17.098496  ...
# 3147                                      5.810054  ...
# 3148                                      5.830267  ...
# 3149                                      3.428022  ...
#
#       Urban population (% of total population)_L5  \
# 5                                       6056809.0
# 6                                       6441501.0
# 7                                       6849440.0
# 8                                       7275437.0
# 9                                       7717606.0
# ...                                           ...
# 3145                                    4371391.0
# 3146                                    4453416.0
# 3147                                    4531324.0
# 3148                                    4610814.0
# 3149                                    4711559.0
#
#       Use of IMF credit (DOD, current US$)_L5  Total_Production_L5  \
# 5                                         0.0         6.328546e+05
# 6                                         0.0         7.159761e+05
# 7                                         0.0         7.410000e+05
# 8                                         0.0         7.308493e+05
# 9                                 374707057.4         7.450603e+05
# ...                                       ...                  ...
# 3145                              528729079.6         2.673301e+06
# 3146                              527094857.9         2.569092e+06
# 3147                              520124249.2         1.601340e+06
# 3148                              519341619.6         3.123499e+06
# 3149                              486727497.2         5.791776e+06
#
#       Total_Reserves_L5  Total_Production_Value_L5  Total_Reserves_Value_L5  \
# 5                3125.0               1.253085e+07             61876.613480
# 6                3695.0               1.614997e+07             83346.553264
# 7                3900.0               1.480903e+07             77942.237484
# 8                4030.0               9.293232e+06             51244.115764
# 9                5050.0               1.284780e+07             87082.036358
# ...                 ...                        ...                      ...
# 3145                0.0               7.536225e+08                 0.000000
# 3146                0.0               6.958915e+08                 0.000000
# 3147                0.0               6.883965e+08                 0.000000
# 3148                0.0               6.338510e+08                 0.000000
# 3149                0.0               6.924206e+08                 0.000000
#
#       Hydrocarbons_Dominant_L5  Subsoil_Metals_Dominant_L5  \
# 5                          1.0                         0.0
# 6                          1.0                         0.0
# 7                          1.0                         0.0
# 8                          1.0                         0.0
# 9                          1.0                         0.0
# ...                        ...                         ...
# 3145                       0.0                         0.0
# 3146                       0.0                         0.0
# 3147                       0.0                         0.0
# 3148                       0.0                         0.0
# 3149                       0.0                         0.0
#
#       Precious_Metals_Dominant_L5  Population_L5
# 5                             0.0     13699778.0
# 6                             0.0     14170973.0
# 7                             0.0     14660413.0
# 8                             0.0     15159370.0
# 9                             0.0     15667235.0
# ...                           ...            ...
# 3145                          1.0     13356548.0
# 3146                          1.0     13595424.0
# 3147                          1.0     13817887.0
# 3148                          1.0     14013808.0
# 3149                          1.0     14207359.0
#
# [2483 rows x 92 columns]

# %%
# ----------------------------
# 1. Drop rows with missing outcome
# ----------------------------
df_clean = master_data.dropna(subset=['Economic Complexity Index']).copy()
df_clean = df_clean.dropna(axis=1, how='all')

# ----------------------------
# 2. Separate outcome and predictors
# ----------------------------
y = df_clean['Economic Complexity Index'].values

X = df_clean.drop(columns=['Country Code', 'Country Name', 'Economic Complexity Index', 'Year', 'Income1995_code']).values
feature_names = df_clean.drop(columns=['Country Code', 'Country Name', 'Economic Complexity Index', 'Year', 'Income1995_code']).columns

# ----------------------------
# 3. Impute missing predictor values
# ----------------------------
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# ----------------------------
# 4. Standardize predictors
# ----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# ----------------------------
# 5. LASSO with cross-validation
# ----------------------------
lasso_cv = LassoCV(cv=10, random_state=42, max_iter=10000)
lasso_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients (indexed by feature names, not rows!)
# ----------------------------
coef = pd.Series(lasso_cv.coef_, index=feature_names)
#print("LASSO coefficients:\n", coef)

# ----------------------------
# 7. Selected predictors (non-zero coefficients)
# ----------------------------
selected = coef[coef != 0].sort_values(key=abs, ascending=False)
#print("Selected predictors:\n", selected)

# ----------------------------
# 8. Optional: Plot
# ----------------------------
plt.figure(figsize=(8,6))
selected.plot(kind='barh')
plt.title("Selected predictors (LASSO)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Ridge

# %%
# ----------------------------
# 5. RIDGE with cross-validation
# ----------------------------
ridge_cv = RidgeCV(
    alphas=np.logspace(-4, 4, 100),
    cv=10
)
ridge_cv.fit(X_scaled, y)

# ----------------------------
# 6. Extract coefficients
# ----------------------------
coef = pd.Series(ridge_cv.coef_, index=feature_names)

# ----------------------------
# 7. Rank predictors by importance
# ----------------------------
ranked = coef.abs().sort_values(ascending=False)

# ----------------------------
# 8. Optional: Plot top coefficients
# ----------------------------
top_k = 20  # change if needed

plt.figure(figsize=(8, 6))
coef.loc[ranked.index[:top_k]].sort_values().plot(kind='barh')
plt.title("Top predictors (Ridge)")
plt.xlabel("Standardized coefficient")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Random Forest

# %%
# ----------------------------
# 6. Random Forest (3 levels)
# ----------------------------
rf = RandomForestRegressor(
    n_estimators=1000,
    max_depth=4,          # <-- 3 levels
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_imputed, y)

# ----------------------------
# 7. Feature importance
# ----------------------------
importance = pd.Series(
    rf.feature_importances_,
    index=feature_names
).sort_values(ascending=False)

#print("Random Forest feature importance:\n", importance)

# ----------------------------
# 7. Plot importance
# ----------------------------
plt.figure(figsize=(16,8))
importance.plot(kind='barh')
plt.title("Feature importance (Random Forest, depth = 3)")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
